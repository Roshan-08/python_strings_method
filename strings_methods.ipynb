# %%
String ="my name is roshan"
st ='Roshan\tkumar'

# %%
#1. String.capitalize()
String.capitalize()
# Out:
# 'My name is roshan'

# %%
# 2.String.casefold()
String.casefold()
# Out:
# 'my name is roshan'

# %%
# 3.String.center()
String.center(25,"*")
# Out:
# '****my name is roshan****'

# %%
# 4.String.count()
String.count('s')
# Out:
# 2

# %%
# 5.String.encode()
String.encode()
# Out:
# b'my name is roshan'

# %%
# 6.String.endswith()
String.endswith('n')
# Out:
# True

# %%
# 7.St.expandtabs()
st='Roshan\tkumar'
st.expandtabs(20)
# Out:
# 'Roshan              kumar'

# %%
# 8.st.find()
st.find("k")
# Out:
# 7

# %%
# 9.st.format()
st='my name is  {} im {} year old'
st.format('Roshan', 22)
# Out:
# 'my name is  Roshan im 22 year old'

# %%
# 10.st.format_map()
st = "Name: {name}, Age: {age}"

data = {"name": "Roshan", "age": 20}

print(st.format_map(data))
# Out:
# Name: Roshan, Age: 20

# %%
# 11.st.index()
st='Roshan'
st.index('n')
# Out:
# 5

# %%
# 12.st.isalnum()  {true: only if contain A-Z, a-z, 0-9  otherwise false}
st ='Roshan_12'
st.isalnum()
# Out:
# False

# %%
# 13.st.isalpha()  {true only if contain A_Z, a-z otherwise false}
st= 'Roshan1'
st.isalpha()
# Out:
# False

# %%
# 14.st.isascii()  {true only if contain ascii (0-127 range) otherwise false}
st ='Roshan_08@'
st.isascii()
# Out:
# True

# %%
# 15.st.isdecimal()  {Checks whether a string contains only decimal digits (0–9)}
st ='8252a'
st.isdecimal()
# Out:
# False

# %%
# 16.st.isdigit()  {Checks whether a string contains only digits, accepts Unicode digits}
st ='2'
st.isdigit()
# Out:
# True

# %%
# 17.st.isidentifier() {Checks whether a string is a valid Python identifier (variable name)}
st ='Roshan_08'
st.isidentifier()
# Out:
# True

# %%
# 18.st.islower()  {Checks whether all letters in the string are lowercase}
st ='Roshan'
st.islower()
# Out:
# False

# %%
# 19.st.isnumeric()  {Checks whether a string contains only numeric characters} 

st ='6/3'
print(st.isnumeric())
print("Ⅻ".isnumeric())
# Out:
# False
# True

# %%
# 20.st.isprintable()  {Checks whether all characters in the string are printable, 
#  \n → newline
# \t → tab
# \r → carriage return}
st= 'roshan\tkumar'
st.isprintable()
# Out:
# False

# %%
# 21.st.isspace()  {Checks whether a string contains only whitespace characters}
print('Roshan\tkumar'.isspace())
st ='\t'
st.isspace()
# Out:
# False
# True

# %%
# 22.st.istitle()  {Checks whether a string is in title case}
st ='Roshan Kumar'
st.istitle()
# Out:
# True

# %%
# 23.st.isupper()  {Checks whether all letters in the string are uppercase}
st ='ROSHAN'
st.isupper()
# Out:
# True

# %%
# 24.st.join()  {Used to join (combine) elements of an iterable (like list, tuple) into a single string}
st= 'Roshan'
'-'.join(st)
# Out:
# 'R-o-s-h-a-n'

# %%
# 25. st.ljust() {Returns a string left-aligned in a given width by adding padding on the right}
st = "Hello"
st.ljust(10, "*")
# Out:
# 'Hello*****'

# %%
# 26. st.lower() {Converts all uppercase letters in a string to lowercase}
st ="Rosahn"
st.lower()
# Out:
# 'rosahn'

# %%
# 27. st.lstrip() {Removes leading (left-side) whitespace or specified characters}
st ='  Roshan'
st.lstrip(' Ro')
# Out:
# 'shan'

# %%
# 28. st.maketrans()
#{Used to create a translation table
# This table is then used with str.translate() to modify strings
# maketrans() does NOT change string directly
# It creates a mapping → used by .translate()}
table = str.maketrans("abc", "xyz")

st = "apple banana cat"
st.translate(table)
# Out:
# 'xpple yxnxnx zxt'

# %%
#29. st.partition() {Splits a string into 3 parts using a separator}
st = "apple-banana-orange"
print(st.partition("-"))

st1 = "hello world"
print(st1.partition(","))

st2 = "Roshan=22"
key, sep, value = st2.partition("=")

print(key)    # key
print(value)  # value
# Out:
# ('apple', '-', 'banana-orange')
# ('hello world', '', '')
# Roshan
# 22

# %%
# 30.st.removeprefix()  {Removes a specified prefix from the string
# If prefix is not present → returns original string}

st= 'unhappy'
st.removeprefix(' un')
# Out:
# 'unhappy'

# %%
# 31. st.removesuffix()
st = 'fighting'
st.removesuffix('ing')
# Out:
# 'fight'

# %%
# 32. st.replace()  {Replaces occurrences of a substring with another substring}
st = "cat cat cat"
print(st.replace("cat", "dog", 2))
# Out:
# dog dog cat

# %%
# 33. st.rfind() {Finds the highest (last) index of a substring in a string
# Searches from right to left}
st = "cat dog cat dog cat"
print(st.rfind("cat"))
# Out:
# 16

# %%
# 34. st.rindex()  {Finds the last occurrence (from right side) of a substring}
# string.rindex(sub, start, end)
st ='aabbccbbaa'
st.rindex('aa')
# Out:
# 8

# %%
# 35. st.rjust() {Returns a string right-aligned by adding padding on the left side}
st = "Hello"
print(st.rjust(10, "*"))
# Out:
# *****Hello

# %%
# 36.st.rpartition() {Splits a string into 3 parts from the RIGHT side (last occurrence)}
# (before_last, separator, after_last)
st = "cat-dog-cat-dog"
print(st.rpartition("-"))
# Out:
# ('cat-dog-cat', '-', 'dog')

# %%
# 37. st.rsplit()  {Splits a string into a list from the right side
# Works like split(), but starts splitting from the end} string.rsplit(separator, maxsplit)
st = "a-b-c-d-e"
print(st.rsplit("-", 2))
# Out:
# ['a-b-c', 'd', 'e']

# %%
# 38. st.rstrip()  {Removes trailing (right-side) whitespace or specified characters}
st = "Hello  *###"
print(st.rstrip(" #"))
# Out:
# Hello  *

# %%
# 39. t.split()  {Splits a string into a list of words/substrings}
st = "ab c d e"
print(st.split(" ",2))
# Out:
# ['ab', 'c', 'd e']

# %%
# 40. st.splitlines()  {Splits a string into a list of words/substrings}
st = "Line1\rLine2\nLine3\r\nLine4"
print(st.splitlines())
# Out:
# ['Line1', 'Line2', 'Line3', 'Line4']

# %%
# 41. st.startswith()
st= 'My name is Roshan'
st.startswith('name')
# Out:
# False

# %%
# 42. st.strip()  {Removes leading (left) and trailing (right) whitespace or specified characters}
st = "###Hel#lo###"
print(st.strip("#"))
# Out:
# Hel#lo

# %%
# 43. st.swapcase  {Converts:  uppercase → lowercase  ;lowercase → uppercase}
st = "PyThOn123@#"
print(st.swapcase())
# Out:
# pYtHoN123@#

# %%
# 44. st.title()
st = "pYtHoN prOgRaMmInG"
print(st.title())
# Out:
# Python Programming

# %%
# 45. st.translate()  {Transforms a string using a translation table (created by str.maketrans())}
# key idea: maketrans() → creates mapping   ;translate() → applies mapping
table = str.maketrans("", "", "aeiou")

st = "hello world"
print(st.translate(table))
# Out:
# hll wrld

# %%
# 46. st.upper()
st ='roshan@08'
st.upper()
# Out:
# 'ROSHAN@08'

# %%
# 47. st.zfill()  {Pads the string with leading zeros (0) until it reaches a specified length}
st = "Rkm%42"
print(st.zfill(10))
# Out:
# 0000Rkm%42
